# %%
#
# Copyright (C) 2018 Pico Technology Ltd. See LICENSE file for terms.
#
# PS2000 BLOCK MODE EXAMPLE
# This example opens a 2000 driver device, sets up two channels and a trigger then collects a block of data.
# This data is then plotted as mV against time in ns.

import ctypes
import numpy as np
from picosdk.ps2000 import ps2000 as ps
import matplotlib.pyplot as plt
from picosdk.functions import adc2mV, assert_pico2000_ok
from picosdk.PicoDeviceEnums import picoEnum

# %%
import matplotlib.pyplot as plt
import asyncio
# %matplotlib widget

# %%
# https://github.com/picotech/picosdk-python-wrappers/blob/master/ps2000Examples/ps2000BlockExample.py
# https://www.picotech.com/download/manuals/picoscope-2000-series-a-api-programmers-guide.pdf

# %%
from src.get_units import get_units
from src.PicoScope import PicoScope

# %%
# %load_ext autoreload
# %autoreload 2

# %%
unit_dict = get_units()
unit_dict
# Out:
# 2 units found
# {'left_bottom': UnitInfo(driver=<picosdk.ps2000.Ps2000lib object at 0x7fcc28096740>, variant=b'2204A', serial=b'JY214/1608'),
#  'right_bottom': UnitInfo(driver=<picosdk.ps2000.Ps2000lib object at 0x7fcc28096740>, variant=b'2204A', serial=b'JY214/1781')}

# %%
lb_ps = PicoScope(unit_dict['left_bottom'], 
                    description='left_bottom')

rb_ps = PicoScope(unit_dict['right_bottom'], 
                    description='right_bottom')

# %%
lb_ps.open_ps()
lb_ps.setup_channels()
lb_ps.setup_simple_trigger(channel=1)
lb_ps.timebase = lb_ps.find_optimal_timebase()

rb_ps.open_ps()
rb_ps.setup_channels()
rb_ps.setup_simple_trigger(channel=1)
rb_ps.timebase = rb_ps.find_optimal_timebase()

# %%
async def update():
    while True:
        lb_time, lb_a, lb_b = lb_ps.block_capture()
        rb_time, rb_a, rb_b = rb_ps.block_capture()
        plt.clf()
        plt.plot(lb_time, lb_a, label='lb_a')
        plt.plot(lb_time, lb_b, label='lb_b')
        plt.plot(rb_time, rb_a, label='rb_a')
        plt.plot(rb_time, rb_a, label='rb_b')
        plt.legend()
        fig.canvas.draw()
        await asyncio.sleep(1)

# %%
fig = plt.figure()

loop = asyncio.get_event_loop()
loop.create_task(update());
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lb_ps.close_ps()
rb_ps.close_ps()

# %%
time, a, b = lb_ps.block_capture()

# %%
plt.plot(time, a)
plt.plot(time, b)

# %%
lb_ps.close_ps()

# %%
rb_ps.close_ps()

# %%
rb_ps.setup_channels()

# %%
    # Set up single trigger
    # handle = chandle
    # source = PS2000_CHANNEL_A = 0
    # threshold = 1024 ADC counts
    # direction = PS2000_RISING = 0
    # delay = 0 s
    # auto Trigger = 1000 ms
    status["trigger"] = ps.ps2000_set_trigger(chandle, 0, 64, 1, 0, 1000)
    assert_pico2000_ok(status["trigger"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 8
#       1 # Set up single trigger
#       2 # handle = chandle
#       3 # source = PS2000_CHANNEL_A = 0
#    (...)
#       6 # delay = 0 s
#       7 # auto Trigger = 1000 ms
# ----> 8 status["trigger"] = ps.ps2000_set_trigger(chandle, 0, 64, 1, 0, 1000)
#       9 assert_pico2000_ok(status["trigger"])
#
# AttributeError: 'Ps2000alib' object has no attribute 'ps2000_set_trigger'

# %%
dont_care = ps.PS2000A_TRIGGER_STATE['PS2000A_CONDITION_DONT_CARE']
trigger_true = ps.PS2000A_TRIGGER_STATE['PS2000A_CONDITION_TRUE']
nConditions = 1

triggerConditions = PS2000A_TRIGGER_CONDITIONS(dont_care,
                                               dont_care,
                                               dont_care,
                                               dont_care,
                                               dont_care,
                                               dont_care,
                                               dont_care,
                                               trigger_true)



status["setTriggerChannelConditions"] = ps.ps2000aSetTriggerChannelConditions(chandle,
                                                                              ctypes.byref(triggerConditions),
                                                                              nConditions)
assert_pico_ok(status["setTriggerChannelConditions"])


digitalChannel = ps.PS2000A_DIGITAL_CHANNEL['PS2000A_DIGITAL_CHANNEL_0']
digiTriggerDirection = ps.PS2000A_DIGITAL_DIRECTION['PS2000A_DIGITAL_DIRECTION_RISING']

digitalDirections = PS2000A_DIGITAL_CHANNEL_DIRECTIONS(digitalChannel, digiTriggerDirection)
nDigitalDirections = 1

status["setTriggerDigitalPortProperties"] = ps.ps2000aSetTriggerDigitalPortProperties(chandle,
                                                                                      ctypes.byref(digitalDirections),
                                                                                      nDigitalDirections)
assert_pico_ok(status["setTriggerDigitalPortProperties"])
# Out:
# [autoreload of src.PicoScope failed: Traceback (most recent call last):
#   File "/home/ryanmueller/Documents/GiantMuonDetector/env/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/ryanmueller/Documents/GiantMuonDetector/env/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 471, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/ryanmueller/Documents/GiantMuonDetector/src/PicoScope.py", line 1, in <module>
#     from picosdk.ps2000 import ps2000 as ps, PS2000A_TRIGGER_CONDITIONS
# ImportError: cannot import name 'PS2000A_TRIGGER_CONDITIONS' from 'picosdk.ps2000' (/home/ryanmueller/Documents/GiantMuonDetector/env/lib/python3.10/site-packages/picosdk/ps2000.py)
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 dont_care = ps.PS2000A_TRIGGER_STATE['PS2000A_CONDITION_DONT_CARE']
#       2 trigger_true = ps.PS2000A_TRIGGER_STATE['PS2000A_CONDITION_TRUE']
#       3 nConditions = 1
#
# AttributeError: 'Ps2000lib' object has no attribute 'PS2000A_TRIGGER_STATE'

# %%
rb_ps.open_ps()
# Out:
# 2

# %%
lb_ps.close_ps()
rb_ps.close_ps()
# Out:
# ---------------------------------------------------------------------------
# PicoSDKCtypesError                        Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 lb_ps.close_ps()
#       2 rb_ps.close_ps()
#
# File ~/Documents/GiantMuonDetector/src/PicoScope.py:45, in PicoScope.close_ps(self)
#      43 def close_ps(self):
#      44     self.status["close"] = ps.ps2000_close_unit(self.chandle)
# ---> 45     return assert_pico2000_ok(self.status["close"])
#
# File ~/Documents/GiantMuonDetector/env/lib/python3.10/site-packages/picosdk/functions.py:174, in assert_pico2000_ok(status)
#     172 else:
#     173     errorCheck = False
# --> 174     raise PicoSDKCtypesError("Unsuccessful API call")
#
# PicoSDKCtypesError: Unsuccessful API call

# %%
while True:
    # Create status ready for use
    status = {}
    
    # Open 2000 series PicoScope
    # Returns handle to chandle for use in future API functions
    status["openUnit"] = ps.ps2000_open_unit()
    assert_pico2000_ok(status["openUnit"])
    
    # Create chandle for use
    chandle = ctypes.c_int16(status["openUnit"])
    
    # Set up channel A
    # handle = chandle
    # channel = PS2000_CHANNEL_A = 0
    # enabled = 1
    # coupling type = PS2000_DC = 1
    # range = PS2000_2V = 7
    # analogue offset = 0 V
    chARange = 7
    status["setChA"] = ps.ps2000_set_channel(chandle, 0, 1, 1, chARange)
    assert_pico2000_ok(status["setChA"])
    
    # Set up channel B
    # handle = chandle
    # channel = PS2000_CHANNEL_B = 1
    # enabled = 1
    # coupling type = PS2000_DC = 1
    # range = PS2000_2V = 7
    # analogue offset = 0 V
    chBRange = 7
    status["setChB"] = ps.ps2000_set_channel(chandle, 1, 1, 1, chBRange)
    assert_pico2000_ok(status["setChB"])
    
    # Set up single trigger
    # handle = chandle
    # source = PS2000_CHANNEL_A = 0
    # threshold = 1024 ADC counts
    # direction = PS2000_RISING = 0
    # delay = 0 s
    # auto Trigger = 1000 ms
    status["trigger"] = ps.ps2000_set_trigger(chandle, 0, 64, 1, 0, 1000)
    assert_pico2000_ok(status["trigger"])
    
    # Set number of pre and post trigger samples to be collected
    preTriggerSamples = 1000
    postTriggerSamples = 1000
    maxSamples = preTriggerSamples + postTriggerSamples
    
    # Get timebase information
    # WARNING: When using this example it may not be possible to access all Timebases as all channels are enabled by default when opening the scope.  
    # To access these Timebases, set any unused analogue channels to off.
    # handle = chandle
    # timebase = 8 = timebase
    # no_of_samples = maxSamples
    # pointer to time_interval = ctypes.byref(timeInterval)
    # pointer to time_units = ctypes.byref(timeUnits)
    # oversample = 1 = oversample
    # pointer to max_samples = ctypes.byref(maxSamplesReturn)
    timebase = 8
    timeInterval = ctypes.c_int32()
    timeUnits = ctypes.c_int32()
    oversample = ctypes.c_int16(1)
    maxSamplesReturn = ctypes.c_int32()
    status["getTimebase"] = ps.ps2000_get_timebase(chandle, timebase, maxSamples, ctypes.byref(timeInterval), ctypes.byref(timeUnits), oversample, ctypes.byref(maxSamplesReturn))
    assert_pico2000_ok(status["getTimebase"])

    # Run block capture
    # handle = chandle
    # no_of_samples = maxSamples
    # timebase = timebase
    # oversample = oversample
    # pointer to time_indisposed_ms = ctypes.byref(timeIndisposedms)
    oversample = ctypes.c_int16(1)
    
    
    timeIndisposedms = ctypes.c_int32()
    status["runBlock"] = ps.ps2000_run_block(chandle, maxSamples, timebase, oversample, ctypes.byref(timeIndisposedms))
    assert_pico2000_ok(status["runBlock"])
    
    # Check for data collection to finish using ps5000aIsReady
    ready = ctypes.c_int16(0)
    check = ctypes.c_int16(0)
    while ready.value == check.value:
        status["isReady"] = ps.ps2000_ready(chandle)
        ready = ctypes.c_int16(status["isReady"])
    
    # Create buffers ready for data
    bufferA = (ctypes.c_int16 * maxSamples)()
    bufferB = (ctypes.c_int16 * maxSamples)()
    
    # Get data from scope
    # handle = chandle
    # pointer to buffer_a = ctypes.byref(bufferA)
    # pointer to buffer_b = ctypes.byref(bufferB)
    # poiner to overflow = ctypes.byref(oversample)
    # no_of_values = cmaxSamples
    cmaxSamples = ctypes.c_int32(maxSamples)
    status["getValues"] = ps.ps2000_get_values(chandle, ctypes.byref(bufferA), ctypes.byref(bufferB), None, None, ctypes.byref(oversample), cmaxSamples)
    assert_pico2000_ok(status["getValues"])
    
    # find maximum ADC count value
    maxADC = ctypes.c_int16(32767)
    
    # convert ADC counts data to mV
    adc2mVChA =  adc2mV(bufferA, chARange, maxADC)
    adc2mVChB =  adc2mV(bufferB, chBRange, maxADC)
    
    # Create time data
    time = np.linspace(0, (cmaxSamples.value -1) * timeInterval.value, cmaxSamples.value)
    
    # plot data from channel A and B
    plt.plot(time, adc2mVChA[:])
    plt.plot(time, adc2mVChB[:])
    plt.xlabel('Time (ns)')
    plt.ylabel('Voltage (mV)')
    plt.show()
    
    # Stop the scope
    # handle = chandle
    status["stop"] = ps.ps2000_stop(chandle)
    assert_pico2000_ok(status["stop"])
    
    # Close unitDisconnect the scope
    # handle = chandle
    status["close"] = ps.ps2000_close_unit(chandle)
    assert_pico2000_ok(status["close"])
    
    # display status returns
    print(status)
# Out:
# {'openUnit': 1, 'setChA': 1, 'setChB': 1, 'trigger': 1, 'getTimebase': 1, 'runBlock': 1, 'isReady': 1, 'getValues': 2000, 'stop': 1, 'close': 1}
# {'openUnit': 1, 'setChA': 1, 'setChB': 1, 'trigger': 1, 'getTimebase': 1, 'runBlock': 1, 'isReady': 1, 'getValues': 2000, 'stop': 1, 'close': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 126
#     122 assert_pico2000_ok(status["stop"])
#     124 # Close unitDisconnect the scope
#     125 # handle = chandle
# --> 126 status["close"] = ps.ps2000_close_unit(chandle)
#     127 assert_pico2000_ok(status["close"])
#     129 # display status returns
#
# KeyboardInterrupt:
